# %% [markdown]
# ## Q1. What is Min-Max scaling, and how is it used in data preprocessing? Provide an example to illustrate its application.

# %% [markdown]
# Min-Max scaling is a normalization technique that enables us to scale data in a dataset to a specific range using each feature’s minimum and maximum value.
#
# For an example, if we have a feauture with data ranging from 0 to 1000 and if we want ot convert the data in the range between -1 and 1 or any range. Min-Max scaling can be used.

# %% [markdown]
# ## Q2. What is the Unit Vector technique in feature scaling, and how does it differ from Min-Max scaling? Provide an example to illustrate its application.

# %% [markdown]
# The Unit Vector technique is a normalization technique that scales each feature vector to have a length of 1, by dividing each data points by magnitude of the vector.
# For an example, if we have a feauture with data ranging from 0 to 1000 and if we want to convert the data to have a vector length of 1, unit vector scaling can be used. However, in min-max scaling the value of each data point is between 0 and 1.

# %% [markdown]
# ## Q3. What is PCA (Principle Component Analysis), and how is it used in dimensionality reduction? Provide an example to illustrate its application.

# %% [markdown]
# Principal Component Analysis (PCA) is a dimensionality reduction technique that enables us to identify correlations and patterns in a dataset so that it can be transformed into a dataset of significantly fewer dimensions without loss of any important information.
#
# PCA works by identifying the principal components of the dataset, which are the directions in which the data varies the most. These principal components are then used to transform the data into a new coordinate system, where the first coordinate has the largest possible variance, the second coordinate has the second-largest variance, and so on.
#
# For example, if we have a dataset with 100 features. We can use PCA to reduce the number of features to 10 while retaining most of the information in the original dataset. If we have a dataset of images with 1000 pixels. We can use PCA to reduce the number of pixels to 100 while retaining most of the information in the original images.

# %% [markdown]
# ## Q4. What is the relationship between PCA and Feature Extraction, and how can PCA be used for Feature Extraction? Provide an example to illustrate this concept.

# %% [markdown]
# Feature extraction is the process of extracting the most important features from the raw data. Similarly, PCA is a dimensionality reduction technique that enables us to identify correlations and patterns in a dataset so that it can be transformed into a dataset of significantly fewer dimensions without loss of any important information. Therefore, both PCA and feature extraction are used to derive the most important features from the raw data.
#
# Eg: if we have a dataset with 100 features. We can use either PCA or feature extraction to reduce the number of features to 10 while retaining most of the information in the original dataset.

# %% [markdown]
# ## Q5. You are working on a project to build a recommendation system for a food delivery service. The dataset contains features such as price, rating, and delivery time. Explain how you would use Min-Max scaling to preprocess the data.

# %% [markdown]
# in this dataset, the units of each feature is different. So, values of each feature has to be normalized so that meaningful comparison between the different features can be done. Therefore, using min-max scaling, the range of price, rating, and delivery time can be brought into a different scale. The price can be transformed between 0 to 1, the rating can be transformed between 0 and 5, and the delivery time can be transformed between 0 and 1.

# %% [markdown]
# ## Q6. You are working on a project to build a model to predict stock prices. The dataset contains many features, such as company financial data and market trends. Explain how you would use PCA to reduce the dimensionality of the dataset.

# %% [markdown]
# If PCA analysis is performed on the dataset, it identifies the principal components of the dataset, which are the directions in which the data varies the most. These principal components are then used to transform the data into a new coordinate system, where the first coordinate has the largest possible variance, the second coordinate has the second-largest variance, and so on. From this, top 10 components of the dataset can be used. Therefore, PCA can be used to reduce the dimentionality of the dataset.

# %% [markdown]
# ## Q7. For a dataset containing the following values: [1, 5, 10, 15, 20], perform Min-Max scaling to transform the values to a range of -1 to 1.

# %%
from sklearn.preprocessing import MinMaxScaler

min_max = MinMaxScaler(feature_range=(-1,1))
data = min_max.fit_transform([[1, 5, 10, 15, 20]])
data
# Out:
# array([[-1., -1., -1., -1., -1.]])

# %% [markdown]
# ## Q8. For a dataset containing the following features: [height, weight, age, gender, blood pressure], perform Feature Extraction using PCA. How many principal components would you choose to retain, and why?

# %% [markdown]
# The explained variance ratio of a principal component measures the proportion of the total variance in the data that is explained by that component.
# For this purpose, random number are created with a hlep of numpy.
#
# The plot shows the explained variance ratio of each principal component as a function of the component number.
#
# When deciding on the number of principal components to retain, one approach is to examine the cumulative sum of the explained variance ratios and choose the number of principal components that explain a sufficient amount of the total variance.
#
# if we examine the cumulative variance plot, we can see that the first three principal components capture approximately 68 % of the total variance. Therefore, retaining the first three principal components may be a reasonable choice for this dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

n_samples = 1000

n_features = 5

X = np.random.rand(n_samples, n_features)

pca = PCA()
pca.fit(X)

explained_variance_ratio = pca.explained_variance_ratio_

plt.plot(np.array([1, 2, 3, 4, 5]), explained_variance_ratio, 'x')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Plot')
plt.show()

# %%
import numpy as np
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)

plt.plot(np.array([1, 2, 3, 4, 5]), cumulative_variance_ratio, 'x')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Cumulative Variance Plot')
plt.show()
